# %% [markdown]
# # F@n Internship DL project 1
#
# ### Classification of Adults Images
#
# インターンの課題：アダルト広告の分類
#
# よくある画像分類のモデル構築ですね。やることは大きく分けてと５つです。
#
# ディープラーニングモデルだからって他の機械学習モデルとは変わらないです。
# > 1. データの取得と前処理
# > 2. モデルの構築
# > 3. モデルの学習
# > 4. 予測
# > 5. モデルの評価
#
# 1週間という短い期間だったのここではモデルのチューニングはあんまりやってないです。（結果さえ出せればいいと思いながら書いたコードです。）

# %% [markdown]
# ## 1. Preprocessing data

# %%
import requests
import pandas as pd
from tqdm import tqdm  # show progress bar
from pathlib import Path # for dowload images
from sklearn.utils import resample # for downsample the data
import numpy as np

parent_url = 'http://13.230.115.40/spool/creative/'

data_urls = pd.read_csv('image_labels.csv')

# %%
# input all images
# create labels
dirs = [('dataset', data_urls.copy())] #directory name and image urls tuples
for d, dat in dirs:
    DIR = Path().cwd().joinpath(d)
    for l in dat.label_name.unique():
        DIR.joinpath(l).mkdir(exist_ok=True)
    for i, x in tqdm(dat.iterrows()):
        with DIR.joinpath(x.label_name).joinpath(x.filename).open('wb') as f:
            res = requests.get(x.link, stream=True)
            if res.ok:
                f.write(res.content)
            else:
                print("ERROR: at {0}".format(x.filename))

# %%
data_urls['label_name'].value_counts() #view data size
# Out:
# not_adult    202140
# adult         52816
# Name: label_name, dtype: int64

# %%
52816/202140 # ratio of labels
# Out:
# 0.2612842584347482

# %%
# remove urls and create our dataset to work
dataset = data_urls.iloc[:,1:]

# %%
# Unfortunetly I can't find a way to process .gif images in Keras so I dropped all data that are .gif
for index, x in dataset.iterrows():
    if '.gif' in dataset.at[index,'filename']:
        dataset.at[index,'filename'] = None

dataset = dataset.dropna()

# %%
n_not_adult = dataset['label_name'].value_counts().not_adult
n_adult = dataset['label_name'].value_counts().adult

print(dataset['label_name'].value_counts())
print("ratio of data: {}".format(n_adult/n_not_adult)) #print ratio
# Out:
# not_adult    135248
# adult         15386
# Name: label_name, dtype: int64
# ratio of data: 0.11376138649000354

# %%
# insert path column
dataset['path'] = None

# insert the path of the images in path column
for index, x in dataset.iterrows():
    dataset.at[index,'path'] = x['label_name'] + "/" + x['filename']

# %%
# Downsample not_adult class
df_not_adult = dataset.query('label_name == "not_adult"')
df_adult = dataset.query('label_name == "adult"')

N = 1 # downsample ratio

df_not_adult_downsampled = resample(df_not_adult,
                                   replace=False,    # sample without replacement
                                   n_samples=n_adult*N, # to match minority class
                                   random_state=43) # reproducible results
df_downsampled = pd.concat([df_not_adult_downsampled, df_adult])

# %%
# import keras modules
from keras.models import Sequential
from keras_preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, Input
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
from keras.applications.inception_v3 import InceptionV3
from keras.models import Model, load_model
from keras.layers.core import Dense
from keras.layers.pooling import GlobalAveragePooling2D
from keras.optimizers import Adam, RMSprop, SGD
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import keras.backend as K

import numpy as np
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto(
    gpu_options=tf.GPUOptions(
        visible_device_list="0", # specify GPU number
        allow_growth=True
    )
)
set_session(tf.Session(config=config))

# %%
from sklearn.model_selection import train_test_split

# split train/test data
traindf, testdf = train_test_split(df_downsampled, test_size = 0.25)

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             validation_split=0.25)

train_generator = train_datagen.flow_from_dataframe(
dataframe=traindf,
directory="./dataset", #if x_col has the full path to the image directory
x_col="path",
y_col="label_name",
subset="training",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(200,200))

valid_generator = train_datagen.flow_from_dataframe(
dataframe=traindf,
directory="./dataset",
x_col="path",
y_col="label_name",
subset="validation",
batch_size=32,
seed=42,
shuffle=True,
class_mode="categorical",
target_size=(200,200))

test_datagen=ImageDataGenerator(rescale=1./255)

test_generator=test_datagen.flow_from_dataframe(
dataframe=testdf,
directory="./dataset",
x_col="path",
y_col="label_name",
batch_size=1,
seed=42,
shuffle=False,
class_mode="categorical",
target_size=(200,200))
# Out:
# Found 17310 images belonging to 2 classes.
# Found 5769 images belonging to 2 classes.
# Found 7693 images belonging to 2 classes.

# %%
# hyper parameters
img_size = 200
nb_train_samples = train_generator.samples
nb_validation_samples = valid_generator.samples
batch_size = 32
nb_epochs = 10

#build the model
input_tensor = Input(shape=(img_size, img_size, 3))
base_model = InceptionV3(include_top = False, weights = "imagenet",
                        input_tensor = input_tensor)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, output=predictions)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 99, 99, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 99, 99, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 99, 99, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 97, 97, 32)   9216        activation_1[0][0]
# ...

# %%
# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable == False

# compile model
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#  create a checkpointer callback to save the best model
checkpointer = ModelCheckpoint(filepath='/home/c_kamiya/dl_project/models/adult_not_adult_model_softmax_2_1.h5', verbose=1, save_best_only=True)
# handling with unbalanced data adjusting class_weights
# class_weights = {0:8.9, 1:1.0} #class_indices {'adult': 0, 'not_adult': 1}

from sklearn.metrics import f1_score
from keras.callbacks import Callback


log = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=10,
    validation_data=valid_generator,
    validation_steps=nb_validation_samples // batch_size,
#     class_weight = class_weights,
    callbacks=[checkpointer]
)

# %%
#Model evaluation with test data
#load model
model_to_eval = load_model("/home/c_kamiya/dl_project/models/adult_not_adult_model_softmax_2_1.h5")

# %%
#%%Model Evaluation
model_to_eval.evaluate_generator(generator=test_generator, steps = test_generator.samples // batch_size, verbose = 1)
#%%
# Out:
# 360/360 [==============================] - 79s 220ms/step
# [0.1686572166884111, 0.9328993055555556]

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

test_pred = model_to_eval.predict_generator(test_generator, steps = test_generator.samples // test_generator.batch_size, verbose = 1)
test_pred = test_pred.argmax(axis=-1)
# Out:
#  489/7693 [>.............................] - ETA: 4:51
# /home/c_kamiya/.conda/envs/keras-gpu/lib/python3.6/site-packages/PIL/Image.py:969: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# 7693/7693 [==============================] - 259s 34ms/step

# %%
test_true = test_generator.labels
print(np.shape(test_pred))
print(np.shape(test_true))
# Out:
# (7693,)
# (7693,)

# %%
# test_true = np.reshape(test_true,(1,np.shape(test_true)[0]))
# test_pred = np.reshape(test_pred,(1,np.shape(test_pred)[0]))
test_generator.samples
# Out:
# 7693

# %%
cm = confusion_matrix(test_true, test_pred) #confusion matrix
acc = accuracy_score(test_true, test_pred) #accuracy
f_score = f1_score(test_true, test_pred) #f-1 score


print("Confusion Matrix:")
print(cm)
print("Accuracy:")
print(acc)
print("F_score")
print(f_score)
# Out:
# Confusion Matrix:
# [[3692  246]
#  [ 143 3612]]
# Accuracy:
# 0.9494345508904198
# F_score
# 0.9489031919085774

# %%
#view predict images
w=1
h=10
fig=plt.figure(figsize=(20, 20))
columns = 4
rows = 5

# test_df = testdf.query("label_name == 'adult'")
test_f_img = testdf[:20]

for j, i in enumerate(test_f_img['path']):
    DIR = Path().cwd().joinpath('dataset')
    file = DIR.joinpath(i)
    img = load_img(file, target_size=(200,200))
    fig.add_subplot(rows, columns, j+1)
    x = img_to_array(img)
    x /= 255
    y_pred = model_to_eval.predict(x.reshape([-1,200,200,3]))
    
    
    if int(y_pred.argmax(axis = -1)) < 0.5:
        plt.title("adult image")
        plt.imshow(img)
    else:
        plt.title("not adult image")
        plt.imshow(img)
        
plt.show()

# %%
#%%
import copy
import grad_cam

#view predict images
w=1
h=10
fig=plt.figure(figsize=(20, 20))
columns = 4
rows = 5

# test_df = testdf.query("label_name == 'adult'")
test_f_img = testdf[:20]

for j, i in enumerate(test_f_img['path']):
    DIR = Path().cwd().joinpath('dataset')
    file = DIR.joinpath(i)
    img = load_img(file, target_size=(200,200))
    fig.add_subplot(rows, columns, j+1)
    x = img_to_array(img)
    x_ = img_to_array(img)
    x /= 255
    
    y_pred = model_to_eval.predict(x.reshape([-1,200,200,3]))
    att_img = grad_cam.Grad_Cam(model_to_eval, x_, "mixed10", img_size)
    att_img = array_to_img(att_img)
    
    if int(y_pred.argmax(axis = -1)) < 0.5:
        plt.title("adult image")
        plt.imshow(att_img)
    else:
        plt.title("not adult image")
        plt.imshow(att_img)
        
plt.show()
